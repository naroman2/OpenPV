# %% [markdown]
# # Steps followed from the following Link:

# %% [markdown]
# https://nsrdb.nrel.gov/data-sets/api-instructions.html

# %% [markdown]
# # Important Sites:

# %% [markdown]
# NSRDB Website: https://nsrdb.nrel.gov
#
# Get NSRDB API Key: https://developer.nrel.gov/signup/
#
# Register to use SAM: https://sam.nrel.gov
#
# Download the SAM Software Development Kit (SDK): https://sam.nrel.gov/sdk
#
# NSRDB download instructions using API: https://developer.nrel.gov.docs/solar/nsrdb/

# %% [markdown]
# # Request and API Key and fill out your info here:

# %%
api_user = 'naroman2@asu.edu'
api_key = 'xvwm5lypqAqWSxnwdny7IzPfrkHKfqg2gDFDV9nk'
api_key = 'xvwm5lypqAqWSxnwdny7IzPfrkHKfqg2gDFDV9nk'

# %% [markdown]
# # Neccessary Python Packages (pip install if you dont have them)

# %%
import pandas as pd
import numpy as np
import sys, os
from IPython.display import display
import requests
import io

# %% [markdown]
# # 1. Request Data From NSRDB using Python API

# %%
# Declare all variables as strings. Spaces must be replaced with '+', i.e., change 'John Smith' to 'John+Smith'.
# Define the lat, long of the location and the year (This data will be grabbed by a google maps embed on our gui)
lat, lon, year = 41.425098, -81.461236, 2010

# Set the attributes to extract (e.g., dhi, ghi, etc.), separated by commas.
attributes = 'ghi,dhi,dni,wind_speed,air_temperature,solar_zenith_angle'

# Set leap year to true or false. True will return leap day data if present, false will not.
leap_year = 'false'

# Set time interval in minutes, i.e., '30' is half hour intervals. Valid intervals are 30 & 60.
interval = '60'

# Specify Coordinated Universal Time (UTC), 'true' will use UTC, 'false' will use the local time zone of the data.
# NOTE: In order to use the NSRDB data in SAM, you must specify UTC as 'false'. SAM requires the data to be in the
# local time zone.
utc = 'false'

# Your full name, use '+' instead of spaces.
your_name = 'Nicolas+Romano'

# Your reason for using the NSRDB.
reason_for_use = 'beta+testing'
# Your affiliation
your_affiliation = 'Arizona+State+University'

# Your email address
your_email = 'naroman2@asu.edu'
# Please join our mailing list so we can keep you up-to-date on new developments.
mailing_list = 'true'

# Declare url string
url = 'https://developer.nrel.gov/api/solar/nsrdb_psm3_download.csv?wkt=POINT({lon}%20{lat})&names={year}&leap_day={leap}&interval={interval}&utc={utc}&full_name={name}&email={email}&affiliation={affiliation}&mailing_list={mailing_list}&reason={reason}&api_key={api}&attributes={attr}'.format(year=year, lat=lat, lon=lon, leap=leap_year, interval=interval, utc=utc, name=your_name, email=api_user, mailing_list=mailing_list, affiliation=your_affiliation, reason=reason_for_use, api=api_key, attr=attributes)

# Return just the first 2 lines to get metadata: (didnt work for me)
# info = pd.read_csv(url, nrows=1)
df = requests.get(url).content
df = pd.read_csv(io.StringIO(df.decode('utf-8')))

# See metadata for specified properties, e.g., timezone and elevation
timezone, elevation = df['Local Time Zone'], df['Elevation']

# %% [markdown]
# # 2. Print out data:

# %%
# Printing data table with first 24 hours:
df.head(24)
# Out:
#    Source Location ID City State Country Latitude Longitude Time Zone  \
# 0   NSRDB     1031109    -     -       -    41.41    -81.46        -5
# 1    Year       Month  Day  Hour  Minute      GHI       DHI       DNI
# 2    2010           1    1     0      30        0         0         0
# 3    2010           1    1     1      30        0         0         0
# 4    2010           1    1     2      30        0         0         0
# 5    2010           1    1     3      30        0         0         0
# 6    2010           1    1     4      30        0         0         0
# 7    2010           1    1     5      30        0         0         0
# 8    2010           1    1     6      30        0         0         0
# 9    2010           1    1     7      30        0         0         0
# 10   2010           1    1     8      30        6         6         0
# 11   2010           1    1     9      30       25        25         0
# ...
